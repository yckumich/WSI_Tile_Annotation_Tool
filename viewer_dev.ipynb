# %%
# from IPython.display import display, HTML
# display(HTML(""" <style> .container { width:100% !important; } :root { --jp-notebook-max-width: 100% !important; } </style> """))

# %%
from widgets.viewer import create_viewer_ui

create_viewer_ui()
