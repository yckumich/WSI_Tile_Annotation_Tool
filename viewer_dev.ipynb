# %%
from widgets.viewer import create_viewer_ui

create_viewer_ui()
# Out:
# FileChooser(path='/Users/yechank/Desktop/mm/projects/WSI_Tile_Annotation_Tool/slides', filename='', title='<b>…
# Text(value='', description='Annotator ID:', layout=Layout(width='300px'), placeholder='e.g. reva', style=TextS…
# Button(button_style='success', description='Load', icon='eye', layout=Layout(margin='10px 0px'), style=ButtonS…
# HTML(value='<i>No slide loaded.</i>')
# Output()
# ...
